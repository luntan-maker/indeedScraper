# %%
# https://www.kaggle.com/code/pierremegret/gensim-word2vec-tutorial/notebook
import pandas as pd
import spacy
from time import time
import re
from collections import defaultdict  # For word frequency

# %%
df=pd.read_csv("1_developer_17_06_2022 08_07_28")
df.shape
# Out:
# (15, 2)

# %%
df.head()
# Out:
#    Unnamed: 0                                               data
# 0           0  Hi,\nHope you are doing great.\nThis is Ashwan...
# 1           1  Roles & Responsibilities\nWrite and optimize S...
# 2           2  Mid-level .Net Developer\nWe are looking for a...
# 3           3  Computer Information Systems, Inc. (CIS) is a ...
# 4           4  Junior Developer at Bay Area's Fastest-Growing...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# data          0
# dtype: int64

# %%
nlp = spacy.load('en_core_web_sm', disable=['ner', 'parser'])

# %%
def cleaning(doc):
    txt = [token.lemma_ for token in doc if not token.is_stop]
    if len(txt) > 2:
        return ' '.join(txt)

# %%
brief_cleaning = (row.lower() for row in df['data'])
brief_cleaning
# Out:
# <generator object <genexpr> at 0x000001C3C5D1B0B0>

# %%
txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000, n_threads=-1)]

# %%
# from nltk.corpus import stopwords
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
nlp = spacy.load("en_core_web_sm", disable=['parser', 'tagger', 'ner'])
stops = stopwords.words("english")

def normalize(comment, lowercase, remove_stopwords):
    if lowercase:
        comment = comment.lower()
    comment = nlp(comment)
    lemmatized = list()
    for word in comment:
        lemma = word.lemma_.strip()
        if lemma:
            if not remove_stopwords or (remove_stopwords and lemma not in stops):
                lemmatized.append(lemma)
    return " ".join(lemmatized)


df['Text_After_Clean'] = df['data'].apply(normalize, lowercase=True, remove_stopwords=True)
df['Text_After_Clean']
# Out:
# 0     hello , hope great . ashwani veridian please g...
# 1     role & responsibility write optimize sql state...
# 2     mid - level .net developer look mid - level .n...
# 3     computer information system , inc . ( cis ) le...
# 4     junior developer bay area fast - grow startup ...
# 5     jr . c # software developer write c # .net cus...
# 6     job responsibility : bachelor degree software ...
# 7     look web developer knowledge experience develo...
# 8     relevant experience : 3 - 5 + year job descrip...
# 9     team ethos group team consist member work coop...
# 10    look full - stack motivate application develop...
# 11    -PRON- look remote junior javascript developer...
# 12    job description experience code use java , c++...
# 13    look java developer experience build high - pe...
# 14    web service : rest soap implement use nodejs e...
# Name: Text_After_Clean, dtype: object

# %%
from gensim.models.phrases import Phrases, Phraser

# %%
sent = [row.split() for row in df['Text_After_Clean']]
sent
arr = []
for i in sent:
    i_arr = []
    for j in i:
        if j not in ['.',',',':','(',')','-',"’",'/','%','$','"', '&', '+', '?']:
#             print(j)
            i_arr.append(j)
    arr.append(i_arr)
    
sent = arr

# %%
phrases = Phrases(sent, min_count=30, progress_per=10000)
# Out:
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words and 0 word types
# collected 3344 token types (unigram + bigrams) from a corpus of 3065 words and 15 sentences
# merged Phrases<3344 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# Phrases lifecycle event {'msg': 'built Phrases<3344 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 0.01s', 'datetime': '2022-06-17T08:59:46.452331', 'gensim': '4.2.0', 'python': '3.8.0 (tags/v3.8.0:fa919fd, Oct 14 2019, 19:37:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}

# %%
bigram = Phraser(phrases)

sentences = bigram[sent]
# Out:
# exporting phrases from Phrases<3344 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000>
# FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<0 phrases, min_count=30, threshold=10.0> from Phrases<3344 vocab, min_count=30, threshold=10.0, max_vocab_size=40000000> in 0.01s', 'datetime': '2022-06-17T08:59:46.758536', 'gensim': '4.2.0', 'python': '3.8.0 (tags/v3.8.0:fa919fd, Oct 14 2019, 19:37:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}

# %%
word_freq = defaultdict(int)
for sent in sentences:
    for i in sent:
        word_freq[i] += 1
len(word_freq)
# Out:
# 953

# %%
sorted(word_freq, key=word_freq.get, reverse=True)[:10]
word_freq
# Out:
# defaultdict(int,
#             {'hello': 1,
#              'hope': 1,
#              'great': 4,
#              'ashwani': 2,
#              'veridian': 1,
#              'please': 4,
#              'go': 3,
#              'job': 28,
#              'description': 4,
#              'let': 2,
#              'know': 2,
#              'interest': 1,
#              'reply': 1,
#              'update': 7,
#              'resume': 1,
#              'expect': 1,
#              'rate': 1,
#              'compensation': 1,
#              'feel': 4,
#              'free': 1,
#              'contact': 1,
#              '832': 2,
#              '391': 2,
#              '5796': 2,
#              'much': 6,
#              'information': 5,
#              'role': 10,
#              'java': 16,
#              'developer': 17,
#              'location': 16,
#              'remote': 24,
#              'duration': 1,
#              'full': 21,
#              'time': 32,
#              'experience': 77,
#              'j2ee': 1,
#              'technology': 10,
#              'restful': 4,
#              'webservices': 1,
#              'spring': 3,
#              'framework': 12,
#              'springboot': 2,
#              'microservices': 1,
#              'javascript': 12,
#              'css': 7,
#              'html': 4,
#              'angular': 9,
#              '4': 2,
#              'software': 17,
#              'development': 43,
#              'life': 10,
#              'cycle': 6,
#              'project': 18,
#              'activity': 1,
#              'maintenance': 3,
#              'ability': 13,
#              'work': 61,
#              'team': 31,
#              'diverse/': 1,
#              'multiple': 2,
#              'stakeholder': 2,
#              'environment': 16,
#              'analytic': 1,
#              'skill': 26,
#              'desire': 5,
#              'global': 2,
#              'delivery': 2,
#              'regard': 1,
#              'kumar': 1,
#              'direct': 2,
#              'www.veridiants.com': 1,
#              '2323': 1,
#              'voss': 1,
#              'road': 1,
#              'ste': 1,
#              '315h': 1,
#              'houston': 1,
#              'tx': 1,
#              '77057': 1,
#              'type': 19,
#              'salary': 8,
#              '68,357.76': 1,
#              '179,749.25': 1,
#              'per': 14,
#              'year': 41,
#              'schedule': 17,
#              'call': 2,
#              'rest': 7,
#              '2': 6,
#              'prefer': 24,
#              'responsibility': 10,
#              'write': 12,
#              'optimize': 1,
#              'sql': 44,
#              'statement': 1,
#              'expertise': 6,
#              'server': 20,
#              'database': 17,
#              'design': 20,
#              'ansi': 1,
#              'nosql': 1,
#              'diva': 1,
#              'deep': 2,
#              'complex': 4,
#              'business': 8,
#              'logic': 4,
#              'well': 6,
#              'practice': 2,
#              'solution': 6,
#              'architecture': 1,
#              'strong': 7,
#              'documentation': 5,
#              'communication': 11,
#              'common': 2,
#              'procedure': 7,
#              'datum': 13,
#              'import': 1,
#              'export': 1,
#              'cleanup': 1,
#              'migration': 1,
#              'etc': 5,
#              'must': 4,
#              'collaborate': 3,
#              'member': 6,
#              'build': 13,
#              'appropriate': 1,
#              'useful': 1,
#              'report': 5,
#              'deliverable': 2,
#              'monitor': 4,
#              'performance': 5,
#              'regular': 1,
#              'basis': 1,
#              'assist': 1,
#              'schema': 3,
#              'code': 14,
#              'review': 6,
#              'query': 4,
#              'tune': 2,
#              'require': 13,
#              'excellent': 6,
#              'understand': 9,
#              'programme': 3,
#              'microsoft': 15,
#              'good': 10,
#              'integration': 5,
#              'service': 14,
#              'ssis': 3,
#              'ssrs': 2,
#              'power': 2,
#              'bi': 2,
#              'tool': 12,
#              'nosql\\newsql': 2,
#              'version': 3,
#              'critical': 5,
#              'thinker': 1,
#              'problem': 4,
#              'solve': 4,
#              'management': 9,
#              'interpersonal': 3,
#              'program': 3,
#              'language': 5,
#              'ms': 3,
#              'studio': 7,
#              'ssdt': 1,
#              '5': 5,
#              'contract': 7,
#              'pay': 23,
#              '55.00': 1,
#              'hour': 18,
#              '8': 9,
#              'shift': 10,
#              '3': 7,
#              'mid': 2,
#              'level': 3,
#              '.net': 7,
#              'look': 13,
#              'enhance': 3,
#              'support': 10,
#              'web': 7,
#              'base': 7,
#              'application': 19,
#              'develope': 7,
#              'asp.net/sql': 1,
#              'majority': 1,
#              'provide': 11,
#              'technical': 15,
#              'production': 2,
#              'daily': 2,
#              'operation': 1,
#              'mention': 1,
#              'vendor': 1,
#              'system': 11,
#              'position': 3,
#              'hand': 4,
#              'c': 11,
#              '#': 11,
#              'visual': 4,
#              'ajax': 1,
#              'webform': 1,
#              'object': 4,
#              'orient': 6,
#              'analysis': 4,
#              'entity': 3,
#              'model': 2,
#              'r': 1,
#              'map': 1,
#              'table': 3,
#              'view': 1,
#              'set': 6,
#              'store': 5,
#              'large': 1,
#              'verbal': 4,
#              'english': 1,
#              'imperative': 1,
#              'operate': 2,
#              'effectively': 3,
#              'across': 2,
#              'use': 25,
#              'agile': 9,
#              'methodology': 5,
#              'plus': 6,
#              '30.00': 3,
#              '50.00': 3,
#              'aw': 3,
#              '1': 24,
#              'asp.net': 4,
#              'apis': 4,
#              'computer': 10,
#              'inc': 1,
#              'cis': 3,
#              'leader': 3,
#              'public': 1,
#              'safety': 3,
#              'federal': 1,
#              'state': 3,
#              'county': 1,
#              'municipal': 1,
#              'agency': 1,
#              'nationwide': 1,
#              'employee': 5,
#              'key': 4,
#              'asset': 1,
#              'commit': 2,
#              'exceptional': 2,
#              'value': 3,
#              'dedication': 1,
#              'encourage': 5,
#              'creativity': 1,
#              'motivate': 4,
#              'excel': 1,
#              'benefit': 12,
#              'include': 10,
#              'employer': 1,
#              'medical': 2,
#              'dental': 7,
#              'short': 1,
#              'term': 1,
#              'insurance': 20,
#              'entry': 1,
#              'play': 2,
#              'deliver': 6,
#              'art': 1,
#              'mission': 4,
#              'minimum': 2,
#              'qualification': 4,
#              'bachelor': 8,
#              '’s': 5,
#              'degree': 8,
#              'science': 8,
#              'relate': 6,
#              'field': 5,
#              'knowledge': 13,
#              'attention': 2,
#              'detail': 4,
#              'organizational': 1,
#              'independently': 3,
#              'multi': 1,
#              'task': 3,
#              'reliable': 1,
#              'highly': 1,
#              'positive': 3,
#              'attitude': 3,
#              'able': 2,
#              'pass': 3,
#              'criminal': 1,
#              'background': 2,
#              'check': 1,
#              'master': 1,
#              'two': 1,
#              'recent': 1,
#              '2019': 1,
#              'n': 1,
#              'tier': 1,
#              'distribute': 3,
#              'protocol': 1,
#              '401(k': 8,
#              'health': 9,
#              'monday': 5,
#              'friday': 5,
#              'education': 4,
#              'junior': 5,
#              'bay': 2,
#              'area': 2,
#              'fast': 2,
#              'grow': 7,
#              'startup': 6,
#              'vote': 1,
#              'place': 1,
#              'five': 1,
#              'san': 1,
#              'francisco': 1,
#              'kinetix': 5,
#              'rapidly': 3,
#              'msp': 1,
#              'manage': 4,
#              'provider': 1,
#              'offer': 3,
#              'tech': 4,
#              'startups': 2,
#              'new': 11,
#              'york': 1,
#              'beyond': 2,
#              'industry': 2,
#              'quickly': 2,
#              'become': 2,
#              'authority': 1,
#              'cybersecurity': 1,
#              'exist': 3,
#              'help': 3,
#              'client': 20,
#              'people': 1,
#              '-PRON-': 14,
#              'dazzle': 1,
#              'want': 2,
#              'expand': 1,
#              'wide': 1,
#              'variety': 2,
#              'also': 2,
#              'learn': 9,
#              'advance': 1,
#              'company': 5,
#              'growth': 3,
#              'senior': 1,
#              'engineer': 7,
#              'take': 6,
#              'internal': 9,
#              'request': 2,
#              'create': 6,
#              'improve': 3,
#              'qol': 1,
#              'teammate': 1,
#              'end': 19,
#              'user': 3,
#              'entail': 1,
#              'primarily': 2,
#              'back': 6,
#              'infrastructure': 1,
#              'though': 2,
#              'may': 1,
#              'opportunity': 4,
#              'front': 12,
#              'future': 1,
#              'someone': 4,
#              'fluent': 1,
#              'node': 1,
#              'js': 2,
#              'proficiency': 2,
#              'powershell': 1,
#              'and/or': 1,
#              'bash': 1,
#              'script': 3,
#              'basic': 2,
#              'git': 6,
#              'workflow': 4,
#              'control': 4,
#              'exposure': 2,
#              'cloud': 3,
#              'platform': 4,
#              'gcp': 1,
#              'azure': 6,
#              'api': 3,
#              'usage': 1,
#              'creation': 1,
#              'postman': 1,
#              'swagger': 2,
#              'think': 2,
#              'outside': 2,
#              'box': 1,
#              'propose': 1,
#              'novel': 1,
#              'assign': 1,
#              'bonus': 5,
#              'point': 1,
#              'window': 1,
#              'unix': 1,
#              'linux': 1,
#              'macos': 1,
#              'low': 2,
#              'automation': 1,
#              'like': 7,
#              'zapier': 1,
#              'even': 2,
#              'meet': 3,
#              'requirement': 8,
#              'still': 1,
#              'qualify': 1,
#              '’d': 1,
#              'apply': 5,
#              '!': 2,
#              'small': 1,
#              'feature': 6,
#              'face': 5,
#              'codebase': 2,
#              'prepare': 2,
#              'maintain': 6,
#              'respond': 2,
#              'error': 1,
#              'bug': 2,
#              'perk': 1,
#              'monthly': 3,
#              'social': 2,
#              'event': 3,
#              'annual': 2,
#              'summer': 1,
#              'holiday': 1,
#              'party': 2,
#              '95': 1,
#              'coverage': 1,
#              'vision': 4,
#              'premium': 1,
#              '125': 1,
#              'reimbursement': 3,
#              '150': 1,
#              'meal': 1,
#              'stipend': 1,
#              '100': 2,
#              'healthy': 1,
#              'live': 1,
#              'expense': 1,
#              'train': 2,
#              'material': 2,
#              'certification': 2,
#              'flexible': 6,
#              'generous': 2,
#              'pto': 1,
#              'sick': 1,
#              'family': 1,
#              'leave': 1,
#              'policy': 1,
#              'covid-19': 4,
#              'pandemic': 3,
#              'impact': 1,
#              'adapt': 2,
#              'current': 4,
#              'situation': 1,
#              'continue': 5,
#              'evolve': 1,
#              'necessary': 3,
#              'big': 1,
#              'concern': 1,
#              'currently': 2,
#              'remotely': 2,
#              'case': 3,
#              'onsite': 1,
#              'visit': 2,
#              'strictly': 1,
#              'adhere': 1,
#              'local': 1,
#              'cdc': 1,
#              'guideline': 1,
#              'pertain': 1,
#              'distance': 1,
#              'personal': 1,
#              'protective': 1,
#              'equipment': 3,
#              'ppe': 1,
#              'precaution': 1,
#              'ensure': 4,
#              'everyone': 3,
#              'safely': 1,
#              'possible': 1,
#              'start': 1,
#              'workforce': 1,
#              'person': 2,
#              'virtual': 1,
#              'one': 2,
#              'find': 2,
#              'way': 3,
#              'keep': 2,
#              'connect': 1,
#              'us': 2,
#              'page': 1,
#              'feedback': 2,
#              'culture': 3,
#              'always': 1,
#              'part': 4,
#              'need': 6,
#              'everything': 1,
#              'welcome': 2,
#              'additional': 1,
#              'home': 1,
#              'office': 1,
#              'continuous': 2,
#              'improvement': 3,
#              'believe': 2,
#              'extend': 1,
#              'far': 2,
#              'credential': 1,
#              'diverse': 1,
#              'inclusive': 1,
#              'workplace': 1,
#              'comfortable': 5,
#              'bring': 1,
#              'authentic': 1,
#              'self': 6,
#              'every': 2,
#              'day': 3,
#              'unique': 1,
#              'perspective': 1,
#              'regardless': 1,
#              'race': 1,
#              'color': 1,
#              'religion': 1,
#              'sex': 1,
#              'sexual': 1,
#              'orientation': 1,
#              'gender': 2,
#              'identity': 1,
#              'expression': 1,
#              'national': 1,
#              'origin': 1,
#              'age': 1,
#              'protect': 1,
#              'veteran': 1,
#              'disable': 1,
#              'status': 3,
#              'genetic': 1,
#              '*': 2,
#              'https://www.kinetix.com/careers/': 1,
#              '60,000.00': 1,
#              '70,000.00': 3,
#              'jr': 1,
#              'customization': 3,
#              'specific': 1,
#              'implementation': 1,
#              'ecommerce': 3,
#              'custom': 2,
#              'wire': 3,
#              'frame': 1,
#              'functional': 1,
#              'approach': 2,
#              'specification': 2,
#              'communicate': 3,
#              'internally': 1,
#              'via': 3,
#              'e': 1,
#              'mail': 1,
#              'phone': 3,
#              'typically': 2,
#              'stand': 2,
#              'format': 2,
#              'similar': 3,
#              'brief': 2,
#              'resolve': 3,
#              'issue': 4,
#              'usually': 1,
#              'screenhero': 1,
#              'gotomeeting': 1,
#              'webex': 1,
#              'style': 1,
#              'follow': 4,
#              'process': 7,
#              'progress': 1,
#              'timeline': 1,
#              'estimate': 2,
#              'order': 1,
#              'debug': 3,
#              'quality': 8,
#              'assurance': 1,
#              'typical': 1,
#              'week': 1,
#              'meeting': 2,
#              'confirm': 1,
#              'facilitate': 1,
#              'pm': 1,
#              'share': 5,
#              'involve': 2,
#              'architecting': 1,
#              'modify': 2,
#              'enterprise': 3,
#              'lightly': 1,
#              'linq': 1,
#              'layer': 1,
#              'validate': 1,
#              'addition': 2,
#              'test': 12,
#              'complete': 3,
#              'trouble': 1,
#              'ticket': 1,
#              'suggest': 1,
#              'weekly': 1,
#              'clarity': 2,
#              'next': 3,
#              '12': 1,
#              '18': 1,
#              'month': 3,
#              'leverage': 1,
#              'standard': 2,
#              'launch': 1,
#              'several': 2,
#              'release': 3,
#              'intelligence': 2,
#              'product': 2,
#              'scrum': 4,
#              'many': 1,
#              'mix': 1,
#              'enable': 2,
#              'challenge': 2,
#              'solid': 1,
#              'consistently': 1,
#              'throughout': 1,
#              'mandatory': 1,
#              'foundation': 1,
#              'jira': 1,
#              'unit': 4,
#              'equivalent': 2,
#              'total': 1,
#              'qa': 1,
#              'directly': 1,
#              'around': 1,
#              'profit': 1,
#              'leadership': 1,
#              'educational': 1,
#              'ongoing': 1,
#              'rapid': 1,
#              'interview': 2,
#              'fax': 1,
#              'contractor': 1,
#              'recruiter': 1,
#              'corp': 2,
#              'consultant': 1,
#              'thorough': 1,
#              'personality': 1,
#              'real': 1,
#              'world': 1,
#              'demand': 1,
#              'excellence': 1,
#              'note': 1,
#              'relocation': 1,
#              'sponsor': 1,
#              'transfer': 1,
#              'visa': 2,
#              '35,000.00': 2,
#              'match': 3,
#              'professional': 7,
#              'assistance': 3,
#              'supplemental': 3,
#              'consideration': 2,
#              'relevant': 4,
#              'collaboration': 3,
#              'source': 1,
#              'react': 8,
#              'soap': 3,
#              'possess': 2,
#              'keen': 1,
#              'eye': 1,
#              'ux': 2,
#              'ada': 1,
#              'compliance': 2,
#              'develop': 4,
#              'component': 3,
#              'innovation': 1,
#              'kanban': 2,
#              'troubleshoot': 3,
#              'habit': 1,
#              'true': 1,
#              'player': 2,
#              'backend': 2,
#              'nodejs': 3,
#              'expressjs': 1,
#              'mysql': 3,
#              'deal': 1,
#              'frontend': 3,
#              'reactjs': 1,
#              'ui': 2,
#              'sass': 1,
#              '-----------': 1,
#              'erp': 2,
#              'join': 2,
#              '----------': 1,
#              '\ufeff1': 2,
#              '90': 2,
#              'trial': 1,
#              'range': 1,
#              'official': 1,
#              'increase': 1,
#              '---------': 2,
#              'mon': 1,
#              'fri': 1,
#              '9:00am': 1,
#              '5:00pm': 1,
#              'pst': 1,
#              'long': 1,
#              'deadline': 2,
#              'another': 1,
#              'guide': 1,
#              'high': 5,
#              '24.00': 1,
#              '35.00': 2,
#              'reside': 1,
#              'u.s': 1,
#              'question(s': 1,
#              'different': 1,
#              'present': 2,
#              'explain': 4,
#              'hoist': 1,
#              'implicit': 1,
#              'coercion': 1,
#              'reference': 1,
#              'immediately': 1,
#              'invoke': 1,
#              'function': 5,
#              '“': 1,
#              '”': 1,
#              'keyword': 1,
#              'difference': 2,
#              'declare': 1,
#              'variable': 1,
#              'var': 1,
#              'const': 1,
#              'uncontrolled': 1,
#              'importance': 1,
#              'rule': 1,
#              'hook': 1,
#              'school': 1,
#              'restapis': 1,
#              'junit': 1,
#              'ethos': 1,
#              'group': 1,
#              'consist': 1,
#              'cooperatively': 1,
#              'initiative': 1,
#              'mentor': 1,
#              'along': 1,
#              'contribute': 3,
#              'idea': 3,
#              'load': 1,
#              'star': 1,
#              'warehouse': 2,
#              'execute': 1,
#              'etl': 1,
#              'package': 2,
#              'move': 1,
#              'establish': 1,
#              'perform': 4,
#              'identify': 1,
#              'pattern': 2,
#              'anomaly': 1,
#              'conversion': 2,
#              'engage': 1,
#              'implement': 2,
#              'index': 1,
#              'constraint': 2,
#              'define': 1,
#              'stay': 1,
#              'concept': 3,
#              'proficiently': 1,
#              'ssms': 1,
#              'aggregate': 1,
#              'relationship': 1,
#              'mis': 1,
#              'within': 1,
#              'structure': 5,
#              'thing': 1,
#              'teamwork': 1,
#              'customer': 3,
#              'would': 2,
#              'beneficial': 1,
#              'saving': 1,
#              'account': 1,
#              'stack': 1,
#              'generation': 1,
#              'risk': 1,
#              'assessment': 1,
#              'add': 1,
#              'ownership': 2,
#              'efficiently': 1,
#              'stable': 1,
#              'functionality': 1,
#              'community': 1,
#              'collaborative': 2,
#              'success': 2,
#              'aspect': 1,
#              'incrementally': 1,
#              'validation': 1,
#              'devops': 2,
#              'passion': 1,
#              'result': 2,
#              'continuously': 1,
#              'outcome': 1,
#              'highlight': 1,
#              'adopt': 2,
#              'prioritize': 1,
#              'pick': 1,
#              'creative': 1,
#              'duty': 1,
#              'strategic': 1,
#              'alongside': 1,
#              'crow': 1,
#              'champion': 1,
#              'innovative': 1,
#              'execution': 1,
#              'give': 1,
#              'chance': 1,
#              'make': 1,
#              'voice': 1,
#              'hear': 1,
#              'open': 1,
#              'agility': 1,
#              'curious': 1,
#              'mind': 1,
#              'pace': 1,
#              'change': 4,
#              'lean': 1,
#              'principle': 1,
#              'micro': 1,
#              'host': 1,
#              'enhancement': 1,
#              'fundamental': 2,
#              'relational': 4,
#              'interact': 1,
#              '75,000.00': 1,
#              'tuition': 1,
#              'europe': 1,
#              'mostly': 1,
#              'talent': 1,
#              'effort': 1,
#              'human^': 1,
#              'student': 2,
#              'university': 2,
#              '/bootcamps': 1,
#              '/self': 1,
#              'teach': 2,
#              'cool': 1,
#              'early': 4,
#              'stage': 4,
#              'gaming': 1,
#              'security': 1,
#              'market': 1,
#              'suit': 1,
#              'pride': 2,
#              'reusable': 3,
#              'frequently': 2,
#              'starter': 2,
#              'uncertainty': 2,
#              'chaos': 2,
#              'designer': 1,
#              'cto': 1,
#              'architect': 1,
#              'scope': 1,
#              'consumer': 1,
#              'alike': 1,
#              'efficient': 2,
#              'abstraction': 1,
#              'productivity': 1,
#              'adoption': 1,
#              'bootcamp': 1,
#              'workable': 1,
#              'little': 1,
#              'modern': 2,
#              'vue': 1,
#              'communicative': 1,
#              'competitive': 1,
#              'commensurate': 1,
#              'wherever': 1,
#              '3,000.00': 1,
#              '5,500.00': 1,
#              'weekend': 1,
#              'determine': 1,
#              'c++': 1,
#              'python': 1,
#              'core': 1,
#              'bootstrap': 1,
#              'oracle': 1,
#              'hibernate': 2,
#              'manual': 1,
#              'familiar': 1,
#              'eclipse': 1,
#              'tomcat': 1,
#              'svn': 1,
#              'fix': 1,
#              'various': 1,
#              'module': 1,
#              'raise': 1,
#              'defect': 1,
#              'splunk': 1,
#              'exception': 1,
#              'b.s': 1,
#              'm.s': 1,
#              'eligibility': 1,
#              'opt': 1,
#              'cpt': 1,
#              'h1b': 1,
#              'f1,ead(gc': 1,
#              'h4': 1,
#              'l2': 1,
#              '50,137.00': 1,
#              '103,044.00': 1,
#              'occupation': 1,
#              'scalable': 1,
#              'grade': 1,
#              'talented': 1,
#              'ee': 2,
#              'lifecycle': 2,
#              'volume': 1,
#              'latency': 1,
#              'phasis': 1,
#              'testable': 1,
#              'produce': 1,
#              'investigate': 1,
#              'alternative': 1,
#              'architectural': 1,
#              'nice': 1,
#              'b': 1,
#              'subject': 1,
#              '6': 1,
#              'prove': 2,
#              'profound': 1,
#              'insight': 1,
#              'jee': 1,
#              'classloading': 1,
#              'memory': 1,
#              'transaction': 1,
#              'orm': 1,
#              'jpa2': 1,
#              'drive': 2,
#              'focus': 1,
#              '75.00': 1,
#              'express': 1,
#              'non': 1,
#              'aurora': 1,
#              'technique': 1,
#              'github': 1,
#              'ci': 1,
#              'cd': 1,
#              'docker': 1,
#              'installation': 1,
#              'angularjs': 1,
#              'incorporate': 1,
#              'tdd': 1,
#              '60,630.02': 1,
#              '140,492.69': 1})

# %%
import multiprocessing

from gensim.models import Word2Vec

# %%
cores = multiprocessing.cpu_count() # Count the number of cores in a computer
# help(Word2Vec)

# %%
w2v_model = Word2Vec(min_count=3,
                     window=5,
                     max_vocab_size=100,
                     sample=6e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     workers=cores-1)
# Out:
# Word2Vec lifecycle event {'params': 'Word2Vec<vocab=0, vector_size=100, alpha=0.03>', 'datetime': '2022-06-17T09:08:52.298828', 'gensim': '4.2.0', 'python': '3.8.0 (tags/v3.8.0:fa919fd, Oct 14 2019, 19:37:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}

# %%
w2v_model.build_vocab(sentences, progress_per=10000)
# Out:
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# pruned out 0 tokens with count <=1 (before 173, after 173)
# pruned out 150 tokens with count <=2 (before 228, after 78)
# pruned out 123 tokens with count <=3 (before 176, after 53)
# pruned out 301 tokens with count <=4 (before 347, after 46)
# pruned out 211 tokens with count <=5 (before 264, after 53)
# pruned out 74 tokens with count <=6 (before 119, after 45)
# pruned out 122 tokens with count <=7 (before 159, after 37)
# pruned out 156 tokens with count <=8 (before 195, after 39)
# pruned out 164 tokens with count <=9 (before 203, after 39)
# pruned out 126 tokens with count <=10 (before 162, after 36)
# pruned out 95 tokens with count <=11 (before 129, after 34)
# pruned out 110 tokens with count <=12 (before 142, after 32)
# collected 68 word types from a corpus of 3065 raw words and 15 sentences
# Creating a fresh vocabulary
# Word2Vec lifecycle event {'msg': 'effective_min_count=3 retains 32 unique words (47.06% of original 68, drops 36)', 'datetime': '2022-06-17T09:08:52.744839', 'gensim': '4.2.0', 'python': '3.8.0 (tags/v3.8.0:fa919fd, Oct 14 2019, 19:37:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# Word2Vec lifecycle event {'msg': 'effective_min_count=3 leaves 802 word corpus (95.59% of original 839, drops 37)', 'datetime': '2022-06-17T09:08:52.745842', 'gensim': '4.2.0', 'python': '3.8.0 (tags/v3.8.0:fa919fd, Oct 14 2019, 19:37:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# deleting the raw counts dictionary of 68 items
# sample=6e-05 downsamples 32 most-common words
# Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 35.67081538716724 word corpus (4.4%% of prior 802)', 'datetime': '2022-06-17T09:08:52.750843', 'gensim': '4.2.0', 'python': '3.8.0 (tags/v3.8.0:fa919fd, Oct 14 2019, 19:37:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'prepare_vocab'}
# estimated required memory for 32 words and 100 dimensions: 41600 bytes
# resetting layer weights
# Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2022-06-17T09:08:52.756626', 'gensim': '4.2.0', 'python': '3.8.0 (tags/v3.8.0:fa919fd, Oct 14 2019, 19:37:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'build_vocab'}

# %%
w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)
# Out:
# Word2Vec lifecycle event {'msg': 'training model with 7 workers on 32 vocabulary and 100 features, using sg=0 hs=0 sample=6e-05 negative=20 window=5 shrink_windows=True', 'datetime': '2022-06-17T09:08:52.977903', 'gensim': '4.2.0', 'python': '3.8.0 (tags/v3.8.0:fa919fd, Oct 14 2019, 19:37:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# EPOCH 0: training on 3065 raw words (39 effective words) took 0.0s, 131757 effective words/s
# EPOCH 1: training on 3065 raw words (46 effective words) took 0.0s, 33956 effective words/s
# EPOCH 2: training on 3065 raw words (32 effective words) took 0.0s, 22645 effective words/s
# EPOCH 3: training on 3065 raw words (35 effective words) took 0.0s, 24265 effective words/s
# EPOCH 4: training on 3065 raw words (39 effective words) took 0.0s, 27523 effective words/s
# EPOCH 5: training on 3065 raw words (31 effective words) took 0.0s, 16130 effective words/s
# EPOCH 6: training on 3065 raw words (32 effective words) took 0.0s, 20865 effective words/s
# EPOCH 7: training on 3065 raw words (36 effective words) took 0.0s, 24346 effective words/s
# EPOCH 8: training on 3065 raw words (39 effective words) took 0.0s, 13155 effective words/s
# EPOCH 9: training on 3065 raw words (39 effective words) took 0.0s, 24186 effective words/s
# EPOCH 10: training on 3065 raw words (25 effective words) took 0.0s, 14529 effective words/s
# EPOCH 11: training on 3065 raw words (45 effective words) took 0.0s, 211665 effective words/s
# EPOCH 12: training on 3065 raw words (37 effective words) took 0.0s, 115157 effective words/s
# EPOCH 13: training on 3065 raw words (42 effective words) took 0.0s, 148673 effective words/s
# EPOCH 14: training on 3065 raw words (40 effective words) took 0.0s, 31213 effective words/s
# EPOCH 15: training on 3065 raw words (30 effective words) took 0.0s, 22545 effective words/s
# EPOCH 16: training on 3065 raw words (43 effective words) took 0.0s, 30224 effective words/s
# EPOCH 17: training on 3065 raw words (29 effective words) took 0.0s, 15514 effective words/s
# EPOCH 18: training on 3065 raw words (36 effective words) took 0.0s, 108860 effective words/s
# EPOCH 19: training on 3065 raw words (40 effective words) took 0.0s, 22442 effective words/s
# EPOCH 20: training on 3065 raw words (22 effective words) took 0.0s, 16020 effective words/s
# EPOCH 21: training on 3065 raw words (34 effective words) took 0.0s, 18446 effective words/s
# EPOCH 22: training on 3065 raw words (39 effective words) took 0.0s, 31599 effective words/s
# EPOCH 23: training on 3065 raw words (45 effective words) took 0.0s, 28721 effective words/s
# EPOCH 24: training on 3065 raw words (50 effective words) took 0.0s, 40183 effective words/s
# EPOCH 25: training on 3065 raw words (46 effective words) took 0.0s, 34984 effective words/s
# EPOCH 26: training on 3065 raw words (39 effective words) took 0.0s, 29474 effective words/s
# EPOCH 27: training on 3065 raw words (39 effective words) took 0.0s, 33621 effective words/s
# EPOCH 28: training on 3065 raw words (34 effective words) took 0.0s, 20387 effective words/s
# EPOCH 29: training on 3065 raw words (41 effective words) took 0.0s, 33717 effective words/s
# Word2Vec lifecycle event {'msg': 'training on 91950 raw words (1124 effective words) took 0.3s, 3587 effective words/s', 'datetime': '2022-06-17T09:08:53.292993', 'gensim': '4.2.0', 'python': '3.8.0 (tags/v3.8.0:fa919fd, Oct 14 2019, 19:37:50) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'train'}
# (1124, 91950)

# %%
w2v_model.init_sims(replace=True)
# Out:
# C:\Users\lucas\AppData\Local\Temp/ipykernel_24232/2897808894.py:1: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   w2v_model.init_sims(replace=True)
# destructive init_sims(replace=True) deprecated & no longer required for space-efficiency

# %%
# w2v_model.wv.most_similar(positive=["java"])
w2v_model.wv.similarity("java", "c")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24232/4269885327.py in <module>
#       1 # w2v_model.wv.most_similar(positive=["java"])
# ----> 2 w2v_model.wv.similarity("java", "c")
#
# c:\python38\lib\site-packages\gensim\models\keyedvectors.py in similarity(self, w1, w2)
#    1236
#    1237         """
# -> 1238         return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#    1239
#    1240     def n_similarity(self, ws1, ws2):
#
# c:\python38\lib\site-packages\gensim\models\keyedvectors.py in __getitem__(self, key_or_keys)
#     402         """
#     403         if isinstance(key_or_keys, _KEY_TYPES):
# --> 404             return self.get_vector(key_or_keys)
#     405
#     406         return vstack([self.get_vector(key) for key in key_or_keys])
#
# c:\python38\lib\site-packages\gensim\models\keyedvectors.py in get_vector(self, key, norm)
#     445
#     446         """
# --> 447         index = self.get_index(key)
#     448         if norm:
#     449             self.fill_norms()
#
# c:\python38\lib\site-packages\gensim\models\keyedvectors.py in get_index(self, key, default)
#     419             return default
#     420         else:
# --> 421             raise KeyError(f"Key '{key}' not present")
#     422
#     423     def get_vector(self, key, norm=False):
#
# KeyError: "Key 'java' not present"

# %%
# help(w2v_model)
w2v_model.corpus_count
# Out:
# 15

# %%
sentences

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
def tsnescatterplot(model, word, list_names):
    """ Plot in seaborn the results from the t-SNE dimensionality reduction algorithm of the vectors of a query word,
    its list of most similar words, and a list of words.
    """
    arrays = np.empty((0, 300), dtype='f')
    word_labels = [word]
    color_list  = ['red']

    # adds the vector of the query word
    arrays = np.append(arrays, model.wv.__getitem__([word]), axis=0)
    
    # gets list of most similar words
    close_words = model.wv.most_similar([word])
    
    # adds the vector for each of the closest words to the array
    for wrd_score in close_words:
        wrd_vector = model.wv.__getitem__([wrd_score[0]])
        word_labels.append(wrd_score[0])
        color_list.append('blue')
        arrays = np.append(arrays, wrd_vector, axis=0)
    
    # adds the vector for each of the words from list_names to the array
    for wrd in list_names:
        wrd_vector = model.wv.__getitem__([wrd])
        word_labels.append(wrd)
        color_list.append('green')
        arrays = np.append(arrays, wrd_vector, axis=0)
        
    # Reduces the dimensionality from 300 to 50 dimensions with PCA
    reduc = PCA(n_components=50).fit_transform(arrays)
    
    # Finds t-SNE coordinates for 2 dimensions
    np.set_printoptions(suppress=True)
    
    Y = TSNE(n_components=2, random_state=0, perplexity=15).fit_transform(reduc)
    
    # Sets everything up to plot
    df = pd.DataFrame({'x': [x for x in Y[:, 0]],
                       'y': [y for y in Y[:, 1]],
                       'words': word_labels,
                       'color': color_list})
    
    fig, _ = plt.subplots()
    fig.set_size_inches(9, 9)
    
    # Basic plot
    p1 = sns.regplot(data=df,
                     x="x",
                     y="y",
                     fit_reg=False,
                     marker="o",
                     scatter_kws={'s': 40,
                                  'facecolors': df['color']
                                 }
                    )
    
    # Adds annotations one by one with a loop
    for line in range(0, df.shape[0]):
         p1.text(df["x"][line],
                 df['y'][line],
                 '  ' + df["words"][line].title(),
                 horizontalalignment='left',
                 verticalalignment='bottom', size='medium',
                 color=df['color'][line],
                 weight='normal'
                ).set_size(15)

    
    plt.xlim(Y[:, 0].min()-50, Y[:, 0].max()+50)
    plt.ylim(Y[:, 1].min()-50, Y[:, 1].max()+50)
            
    plt.title('t-SNE visualization for {}'.format(word.title()))

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
l = linkage(w2v_model.wv.vectors, method='complete', metric='seuclidean')

plt.figure(figsize=(25,10))
dendrogram(
    l,
    leaf_rotation=90.,
    leaf_font_size=16.,
    orientation='left',
    leaf_label_func=lambda v: str(w2v_model.wv.index_to_key[v])
)
plt.show()
